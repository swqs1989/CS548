# %% [markdown]
# ### Preprocess the data

# %%
import pandas as pd

# %%
# 
df_data = pd.read_table("processed.cleveland.data", 
                        sep=',', 
                        names=["age","sex","cp","trestbps","chol","fbs","restecg",
                               "thalach","exang","oldpeak","slope","ca","thal","num"])

# %%
df_data
# Out:
#       age     sex                cp  trestbps   chol    fbs  \
# 0    63.0    male    typical angina     145.0  233.0   true
# 1    67.0    male      asymptomatic     160.0  286.0  false
# 2    67.0    male      asymptomatic     120.0  229.0  false
# 3    37.0    male  non-anginal pain     130.0  250.0  false
# 4    41.0  female   atypical angina     130.0  204.0  false
# 5    56.0    male   atypical angina     120.0  236.0  false
# 6    62.0  female      asymptomatic     140.0  268.0  false
# 7    57.0  female      asymptomatic     120.0  354.0  false
# 8    63.0    male      asymptomatic     130.0  254.0  false
# 9    53.0    male      asymptomatic     140.0  203.0   true
# 10   57.0    male      asymptomatic     140.0  192.0  false
# 11   56.0  female   atypical angina     140.0  294.0  false
# 12   56.0    male  non-anginal pain     130.0  256.0   true
# 13   44.0    male   atypical angina     120.0  263.0  false
# 14   52.0    male  non-anginal pain     172.0  199.0   true
# 15   57.0    male  non-anginal pain     150.0  168.0  false
# 16   48.0    male   atypical angina     110.0  229.0  false
# 17   54.0    male      asymptomatic     140.0  239.0  false
# 18   48.0  female  non-anginal pain     130.0  275.0  false
# 19   49.0    male   atypical angina     130.0  266.0  false
# 20   64.0    male    typical angina     110.0  211.0  false
# 21   58.0  female    typical angina     150.0  283.0   true
# 22   58.0    male   atypical angina     120.0  284.0  false
# 23   58.0    male  non-anginal pain     132.0  224.0  false
# 24   60.0    male      asymptomatic     130.0  206.0  false
# 25   50.0  female  non-anginal pain     120.0  219.0  false
# 26   58.0  female  non-anginal pain     120.0  340.0  false
# 27   66.0  female    typical angina     150.0  226.0  false
# 28   43.0    male      asymptomatic     150.0  247.0  false
# 29   40.0    male      asymptomatic     110.0  167.0  false
# ..    ...     ...               ...       ...    ...    ...
# 273  71.0  female      asymptomatic     112.0  149.0  false
# 274  59.0    male    typical angina     134.0  204.0  false
# 275  64.0    male    typical angina     170.0  227.0  false
# 276  66.0  female  non-anginal pain     146.0  278.0  false
# 277  39.0  female  non-anginal pain     138.0  220.0  false
# 278  57.0    male   atypical angina     154.0  232.0  false
# 279  58.0  female      asymptomatic     130.0  197.0  false
# 280  57.0    male      asymptomatic     110.0  335.0  false
# 281  47.0    male  non-anginal pain     130.0  253.0  false
# 282  55.0  female      asymptomatic     128.0  205.0  false
# 283  35.0    male   atypical angina     122.0  192.0  false
# 284  61.0    male      asymptomatic     148.0  203.0  false
# 285  58.0    male      asymptomatic     114.0  318.0  false
# 286  58.0  female      asymptomatic     170.0  225.0   true
# 287  58.0    male   atypical angina     125.0  220.0  false
# 288  56.0    male   atypical angina     130.0  221.0  false
# 289  56.0    male   atypical angina     120.0  240.0  false
# 290  67.0    male  non-anginal pain     152.0  212.0  false
# 291  55.0  female   atypical angina     132.0  342.0  false
# 292  44.0    male      asymptomatic     120.0  169.0  false
# 293  63.0    male      asymptomatic     140.0  187.0  false
# 294  63.0  female      asymptomatic     124.0  197.0  false
# 295  41.0    male   atypical angina     120.0  157.0  false
# 296  59.0    male      asymptomatic     164.0  176.0   true
# 297  57.0  female      asymptomatic     140.0  241.0  false
# 298  45.0    male    typical angina     110.0  264.0  false
# 299  68.0    male      asymptomatic     144.0  193.0   true
# 300  57.0    male      asymptomatic     130.0  131.0  false
# 301  57.0  female   atypical angina     130.0  236.0  false
# 302  38.0    male  non-anginal pain     138.0  175.0  false
#
#                    restecg  thalach exang  oldpeak        slope   ca thal  num
# 0              hypertrophy    150.0    no      2.3  downsloping  0.0  6.0    0
# 1              hypertrophy    108.0   yes      1.5         flat  3.0  3.0    2
# 2              hypertrophy    129.0   yes      2.6         flat  2.0  7.0    1
# 3                   normal    187.0    no      3.5  downsloping  0.0  3.0    0
# 4              hypertrophy    172.0    no      1.4    upsloping  0.0  3.0    0
# 5                   normal    178.0    no      0.8    upsloping  0.0  3.0    0
# 6              hypertrophy    160.0    no      3.6  downsloping  2.0  3.0    3
# 7                   normal    163.0   yes      0.6    upsloping  0.0  3.0    0
# 8              hypertrophy    147.0    no      1.4         flat  1.0  7.0    2
# 9              hypertrophy    155.0   yes      3.1  downsloping  0.0  7.0    1
# 10                  normal    148.0    no      0.4         flat  0.0  6.0    0
# 11             hypertrophy    153.0    no      1.3         flat  0.0  3.0    0
# 12             hypertrophy    142.0   yes      0.6         flat  1.0  6.0    2
# 13                  normal    173.0    no      0.0    upsloping  0.0  7.0    0
# 14                  normal    162.0    no      0.5    upsloping  0.0  7.0    0
# 15                  normal    174.0    no      1.6    upsloping  0.0  3.0    0
# 16                  normal    168.0    no      1.0  downsloping  0.0  7.0    1
# 17                  normal    160.0    no      1.2    upsloping  0.0  3.0    0
# 18                  normal    139.0    no      0.2    upsloping  0.0  3.0    0
# 19                  normal    171.0    no      0.6    upsloping  0.0  3.0    0
# 20             hypertrophy    144.0   yes      1.8         flat  0.0  3.0    0
# 21             hypertrophy    162.0    no      1.0    upsloping  0.0  3.0    0
# 22             hypertrophy    160.0    no      1.8         flat  0.0  3.0    1
# 23             hypertrophy    173.0    no      3.2    upsloping  2.0  7.0    3
# 24             hypertrophy    132.0   yes      2.4         flat  2.0  7.0    4
# 25                  normal    158.0    no      1.6         flat  0.0  3.0    0
# 26                  normal    172.0    no      0.0    upsloping  0.0  3.0    0
# 27                  normal    114.0    no      2.6  downsloping  0.0  3.0    0
# 28                  normal    171.0    no      1.5    upsloping  0.0  3.0    0
# 29             hypertrophy    114.0   yes      2.0         flat  0.0  7.0    3
# ..                     ...      ...   ...      ...          ...  ...  ...  ...
# 273                 normal    125.0    no      1.6         flat  0.0  3.0    0
# 274                 normal    162.0    no      0.8    upsloping  2.0  3.0    1
# 275            hypertrophy    155.0    no      0.6         flat  0.0  7.0    0
# 276            hypertrophy    152.0    no      0.0         flat  1.0  3.0    0
# 277                 normal    152.0    no      0.0         flat  0.0  3.0    0
# 278            hypertrophy    164.0    no      0.0    upsloping  1.0  3.0    1
# 279                 normal    131.0    no      0.6         flat  0.0  3.0    0
# 280                 normal    143.0   yes      3.0         flat  1.0  7.0    2
# 281                 normal    179.0    no      0.0    upsloping  0.0  3.0    0
# 282  ST-T wave abnormality    130.0   yes      2.0         flat  1.0  7.0    3
# 283                 normal    174.0    no      0.0    upsloping  0.0  3.0    0
# 284                 normal    161.0    no      0.0    upsloping  1.0  7.0    2
# 285  ST-T wave abnormality    140.0    no      4.4  downsloping  3.0  6.0    4
# 286            hypertrophy    146.0   yes      2.8         flat  2.0  6.0    2
# 287                 normal    144.0    no      0.4         flat    ?  7.0    0
# 288            hypertrophy    163.0    no      0.0    upsloping  0.0  7.0    0
# 289                 normal    169.0    no      0.0  downsloping  0.0  3.0    0
# 290            hypertrophy    150.0    no      0.8         flat  0.0  7.0    1
# 291                 normal    166.0    no      1.2    upsloping  0.0  3.0    0
# 292                 normal    144.0   yes      2.8  downsloping  0.0  6.0    2
# 293            hypertrophy    144.0   yes      4.0    upsloping  2.0  7.0    2
# 294                 normal    136.0   yes      0.0         flat  0.0  3.0    1
# 295                 normal    182.0    no      0.0    upsloping  0.0  3.0    0
# 296            hypertrophy     90.0    no      1.0         flat  2.0  6.0    3
# 297                 normal    123.0   yes      0.2         flat  0.0  7.0    1
# 298                 normal    132.0    no      1.2         flat  0.0  7.0    1
# 299                 normal    141.0    no      3.4         flat  2.0  7.0    2
# 300                 normal    115.0   yes      1.2         flat  1.0  7.0    3
# 301            hypertrophy    174.0    no      0.0         flat  1.0  3.0    1
# 302                 normal    173.0    no      0.0    upsloping    ?  3.0    0
#
# [303 rows x 14 columns]

# %%
df_data["sex"] = df_data["sex"].replace(1.0, "male")
df_data["sex"] = df_data["sex"].replace(0.0, "female")

# %%
df_data["cp"] = df_data["cp"].replace(1.0, "typical angina")
df_data["cp"] = df_data["cp"].replace(2.0, "atypical angina")
df_data["cp"] = df_data["cp"].replace(3.0, "non-anginal pain")
df_data["cp"] = df_data["cp"].replace(4.0, "asymptomatic")

# %%
df_data["fbs"] = df_data["fbs"].replace(1.0, "true")
df_data["fbs"] = df_data["fbs"].replace(0.0, "false")

# %%
df_data["restecg"] = df_data["restecg"].replace(0.0, "normal")
df_data["restecg"] = df_data["restecg"].replace(1.0, "ST-T wave abnormality")
df_data["restecg"] = df_data["restecg"].replace(2.0, "hypertrophy")

# %%
df_data["exang"] = df_data["exang"].replace(1.0, "yes")
df_data["exang"] = df_data["exang"].replace(0.0, "no")

# %%
df_data["slope"] = df_data["slope"].replace(1.0, "upsloping")
df_data["slope"] = df_data["slope"].replace(2.0, "flat")
df_data["slope"] = df_data["slope"].replace(3.0, "downsloping")

# %%
df_data["thal"] = df_data["thal"].replace(3.0, "normal")
df_data["thal"] = df_data["thal"].replace(6.0, "fixed defect")
df_data["thal"] = df_data["thal"].replace(7.0, "reversable defect")

# %%
df_data["thal"]
# Out:
# 0      6.0
# 1      3.0
# 2      7.0
# 3      3.0
# 4      3.0
# 5      3.0
# 6      3.0
# 7      3.0
# 8      7.0
# 9      7.0
# 10     6.0
# 11     3.0
# 12     6.0
# 13     7.0
# 14     7.0
# 15     3.0
# 16     7.0
# 17     3.0
# 18     3.0
# 19     3.0
# 20     3.0
# 21     3.0
# 22     3.0
# 23     7.0
# 24     7.0
# 25     3.0
# 26     3.0
# 27     3.0
# 28     3.0
# 29     7.0
#       ...
# 273    3.0
# 274    3.0
# 275    7.0
# 276    3.0
# 277    3.0
# 278    3.0
# 279    3.0
# 280    7.0
# 281    3.0
# 282    7.0
# 283    3.0
# 284    7.0
# 285    6.0
# 286    6.0
# 287    7.0
# 288    7.0
# 289    3.0
# 290    7.0
# 291    3.0
# 292    6.0
# 293    7.0
# 294    3.0
# 295    3.0
# 296    6.0
# 297    7.0
# 298    7.0
# 299    7.0
# 300    7.0
# 301    3.0
# 302    3.0
# Name: thal, dtype: object
